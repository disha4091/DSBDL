# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('dataset_Facebook.csv', delimiter=";")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %% [markdown]
# ### Creating subset

# %%
photo_sub = df[df['Type']=='Photo']
photo_sub.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
status_sub = df[df['Type']=='Status']
status_sub.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
Link_sub = df[df['Type']=='Link']
Link_sub.head()
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
video_sub = df[df['Type']=='Video']
video_sub.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ### Merge subsets

# %%
df_media = pd.merge(photo_sub, video_sub, how="outer")
df_media
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 1              139441  Photo         3          12             3          3
# 2              139441  Photo         2          12             2         10
# 3              139441  Photo         2          12             2          3
# 4              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 423            137893  Video         1          11             5          3
# 424            137893  Video         1          11             3         11
# 425            134879  Video         1           9             2         10
# 426            130791  Video         1           7             3         11
# 427            126424  Video         1           6             2         13
#
# ...

# %% [markdown]
# ### Sort according to page total likes

# %%
df.sort_values('Page total likes')
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 496             81370   Photo         2           1             5          8
# 493             85093   Photo         3           1             1          2
# 495             85093   Photo         3           1             7          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
df_transpose = photo_sub.transpose()
df_transpose
# Out:
#                                                        0       2       3    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo   Photo   Photo
# Category                                                 2       3       2
# Post Month                                              12      12      12
# Post Weekday                                             4       3       2
# Post Hour                                                3       3      10
# Paid                                                   0.0     0.0     1.0
# Lifetime Post Total Reach                             2752    2413   50128
# Lifetime Post Total Impressions                       5091    4373   87991
# Lifetime Engaged Users                                 178     177    2211
# Lifetime Post Consumers                                109     113     790
# ...

# %%
df_melt = pd.melt(photo_sub,id_vars=['Type','comment'], value_vars='like')
df_melt
# Out:
#       Type  comment variable   value
# 0    Photo        4     like    79.0
# 1    Photo        0     like    66.0
# 2    Photo       58     like  1572.0
# 3    Photo       19     like   325.0
# 4    Photo        3     like   249.0
# ..     ...      ...      ...     ...
# 416  Photo       10     like   125.0
# 417  Photo        5     like    53.0
# 418  Photo        0     like    53.0
# 419  Photo        4     like    93.0
# 420  Photo        7     like    91.0
#
# [421 rows x 4 columns]

# %%
df_cast = pd.pivot_table(df, values=['like','comment'], index='Type', aggfunc='sum')

# %%
df_cast
# Out:
#         comment     like
# Type
# Link         62   1613.0
# Photo      3192  77492.0
# Status      401   7952.0
# Video        86   1620.0
